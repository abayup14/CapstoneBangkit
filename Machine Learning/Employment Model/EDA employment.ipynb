# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df=pd.read_excel('employment.xlsx')
df.head(10)
# Out:
#    Unnamed: 0.1  Unnamed: 0  Age Accessibility        EdLevel  Employment  \
# 0             0           0  <35            No         Master           1
# 1             1           1  <35            No  Undergraduate           1
# 2             2           2  <35            No         Master           1
# 3             3           3  <35            No  Undergraduate           1
# 4             4           4  >35            No            PhD           0
# 5             5           5  <35            No         Master           1
# 6             6           6  >35            No         Master           1
# 7             7           7  <35            No         Master           1
# 8             8           8  >35            No  Undergraduate           1
# 9             9           9  >35            No         Master           1
#
#   Gender MentalHealth MainBranch  YearsExp  YearsProExp  \
# 0    Man           No        Dev         7            4
# 1    Man           No        Dev        12            5
# 2    Man           No        Dev        15            6
# 3    Man           No        Dev         9            6
# 4    Man           No     NotDev        40           30
# 5    Man           No        Dev         9            2
# 6    Man           No        Dev        26           18
# 7    Man           No     NotDev        14            5
# 8    Man           No        Dev        39           21
# 9    Man           No        Dev        20           16
#
#                                              Country  PreviousSalary  \
# 0                                             Sweden           51552
# 1                                              Spain           46482
# 2                                            Germany           77290
# 3                                             Canada           46135
# 4                                          Singapore          160932
# 5                                             France           38915
# 6                                            Germany           77831
# 7                                        Switzerland           81319
# 8  United Kingdom of Great Britain and Northern I...           68507
# 9                                 Russian Federation           37752
#
#                                       HaveWorkedWith  NumSkills  Employed
# 0                          C++;Python;Git;PostgreSQL          4         0
# 1  Bash/Shell;HTML/CSS;JavaScript;Node.js;SQL;Typ...         12         1
# 2             C;C++;Java;Perl;Ruby;Git;Ruby on Rails          7         0
# 3  Bash/Shell;HTML/CSS;JavaScript;PHP;Ruby;SQL;Gi...         13         0
# 4                                         C++;Python          2         0
# 5                 JavaScript;Python;Docker;Git;MySQL          5         0
# 6  C++;HTML/CSS;Java;JavaScript;Kotlin;Node.js;Ty...         17         1
# 7                              C++;Python;Docker;Git          4         0
# 8                              Python;Git;PostgreSQL          3         0
# 9              Delphi;Java;SQL;Docker;Git;PostgreSQL          6         0

# %%
df_drop=df.drop(['Unnamed: 0.1', 'Unnamed: 0', 'HaveWorkedWith', 'Gender', 'Country'], axis=1)

# %%
print(df_drop.columns)
# Out:
# Index(['Age', 'Accessibility', 'EdLevel', 'Employment', 'MentalHealth',
#        'MainBranch', 'YearsExp', 'YearsProExp', 'PreviousSalary', 'NumSkills',
#        'Employed'],
#       dtype='object')

# %%
col=df_drop.columns
plt.subplots(figsize=(20,15))
plt.delaxes()
for i in range(len(df_drop.columns)):
    plt.subplot(3,4,i+1)
    plt.hist(df_drop[col[i]])
    plt.title(col[i])
plt.show()

# %%
col_pie=['Age', 'Accessibility', 'EdLevel', 'Employment', 'MentalHealth', 'MainBranch', 'Employed']
plt.subplots(figsize=(20,10))
plt.delaxes()
for i in range(len(col_pie)):
    plt.subplot(2,4,i+1)
    list_count=[]
    list_key=list(set(df_drop[col_pie[i]]))
    for sets in list_key:
        list_count.append(sum(df_drop[col_pie[i]]==sets))
    plt.pie(list_count, labels=list_key, autopct='%1.2f%%')
    plt.title(col_pie[i])
plt.show()

# %%
col_box=["PreviousSalary", "NumSkills", "YearsExp", "YearsProExp"]
plt.subplots(figsize=(10,10))
plt.delaxes()
i=1
for col in col_box:
    plt.subplot(2,2,i)
    plt.boxplot(df_drop[col])
    plt.title(col)
    i+=1
plt.show()

# %%
df_drop.to_csv("EDA.csv")
