# %%
import tensorflow as tf
import keras
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# 2023-10-21 18:52:24.191184: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-10-21 18:52:24.191246: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-10-21 18:52:24.191265: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2023-10-21 18:52:24.197479: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df=pd.read_excel("preprocessed.xlsx")

# %%
df.drop(['Unnamed: 0'], axis=1, inplace=True)
df.drop(['HaveWorkedWith'], axis=1, inplace=True)
print(df.columns)
# Out:
# Index(['Age', 'Accessibility', 'EdLevel', 'Employment', 'MentalHealth',
#        'MainBranch', 'YearsCode', 'YearsCodePro', 'PreviousSalary',
#        'ComputerSkills', 'Employed'],
#       dtype='object')

# %%
def split(df, train_split=0.8, val_split=0.1, test_split=0.1):
    df_sample = df.sample(frac=1, random_state=12)
    indices_or_sections = [int(train_split * len(df)), int((1 - val_split - test_split) * len(df))]
    train, val, test = np.split(df_sample, indices_or_sections)
    return train, val, test
train, val, test=split(df, 0.9,0,0.1)
train_x=train.drop(['Employed'], axis=1)
train_y=train['Employed']
# Out:
# /home/abayup14/.local/lib/python3.10/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)

# %%
model=keras.Sequential([
    keras.layers.Dense(12, activation='relu'),
    keras.layers.Dense(10, activation='relu'),
    keras.layers.Dense(2, activation='linear')
])
# Out:
# 2023-10-21 18:54:36.046688: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:36.234837: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:36.234881: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:36.239840: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:36.239882: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:36.239900: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:37.290718: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:37.290842: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:37.290880: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1977] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2023-10-21 18:54:37.290954: I tensorflow/core/common_runtime/gpu/gpu_process_state.cc:236] Using CUDA malloc Async allocator for GPU: 0
# 2023-10-21 18:54:37.291361: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:880] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2023-10-21 18:54:37.291473: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1886] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1592 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
    metrics=['accuracy']
    )
history=model.fit(train_x, train_y,
                  validation_split = 0.1, 
                  epochs=50,
                  verbose=2
                 )
# Out:
# Epoch 1/50
# 2023-10-21 18:54:56.615262: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x7f0d0a09cca0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-10-21 18:54:56.615305: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 Laptop GPU, Compute Capability 8.6
# 2023-10-21 18:54:56.625263: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-10-21 18:54:56.869411: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:442] Loaded cuDNN version 8700
# 2023-10-21 18:54:56.959794: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1860/1860 - 10s - loss: 95.9808 - accuracy: 0.5225 - val_loss: 23.4932 - val_accuracy: 0.5014 - 10s/epoch - 5ms/step
# Epoch 2/50
# 1860/1860 - 6s - loss: 28.9936 - accuracy: 0.5494 - val_loss: 5.7833 - val_accuracy: 0.6101 - 6s/epoch - 3ms/step
# Epoch 3/50
# 1860/1860 - 6s - loss: 21.8289 - accuracy: 0.5728 - val_loss: 4.6035 - val_accuracy: 0.6162 - 6s/epoch - 3ms/step
# Epoch 4/50
# 1860/1860 - 6s - loss: 19.9043 - accuracy: 0.5894 - val_loss: 1.9393 - val_accuracy: 0.7402 - 6s/epoch - 3ms/step
# Epoch 5/50
# 1860/1860 - 6s - loss: 15.5746 - accuracy: 0.6137 - val_loss: 25.8098 - val_accuracy: 0.5411 - 6s/epoch - 3ms/step
# Epoch 6/50
# 1860/1860 - 7s - loss: 13.4477 - accuracy: 0.6261 - val_loss: 10.1925 - val_accuracy: 0.6103 - 7s/epoch - 4ms/step
# Epoch 7/50
# 1860/1860 - 6s - loss: 12.8879 - accuracy: 0.6384 - val_loss: 18.1062 - val_accuracy: 0.5723 - 6s/epoch - 3ms/step
# Epoch 8/50
# 1860/1860 - 7s - loss: 10.3061 - accuracy: 0.6507 - val_loss: 10.0438 - val_accuracy: 0.6006 - 7s/epoch - 4ms/step
# Epoch 9/50
# 1860/1860 - 6s - loss: 8.7982 - accuracy: 0.6558 - val_loss: 10.4659 - val_accuracy: 0.6016 - 6s/epoch - 3ms/step
# Epoch 10/50
# 1860/1860 - 6s - loss: 8.4636 - accuracy: 0.6568 - val_loss: 4.8747 - val_accuracy: 0.6670 - 6s/epoch - 3ms/step
# Epoch 11/50
# 1860/1860 - 7s - loss: 7.2371 - accuracy: 0.6727 - val_loss: 7.5980 - val_accuracy: 0.6292 - 7s/epoch - 4ms/step
# Epoch 12/50
# 1860/1860 - 7s - loss: 8.0795 - accuracy: 0.6717 - val_loss: 21.5277 - val_accuracy: 0.5702 - 7s/epoch - 4ms/step
# Epoch 13/50
# 1860/1860 - 6s - loss: 8.2776 - accuracy: 0.6639 - val_loss: 11.7386 - val_accuracy: 0.5986 - 6s/epoch - 3ms/step
# Epoch 14/50
# 1860/1860 - 6s - loss: 6.9940 - accuracy: 0.6749 - val_loss: 1.6313 - val_accuracy: 0.7786 - 6s/epoch - 3ms/step
# Epoch 15/50
# 1860/1860 - 6s - loss: 6.3483 - accuracy: 0.6876 - val_loss: 8.4367 - val_accuracy: 0.6154 - 6s/epoch - 3ms/step
# Epoch 16/50
# 1860/1860 - 6s - loss: 5.1765 - accuracy: 0.6946 - val_loss: 6.7116 - val_accuracy: 0.6370 - 6s/epoch - 3ms/step
# Epoch 17/50
# 1860/1860 - 6s - loss: 6.2297 - accuracy: 0.6784 - val_loss: 4.7116 - val_accuracy: 0.6617 - 6s/epoch - 3ms/step
# Epoch 18/50
# 1860/1860 - 7s - loss: 4.9470 - accuracy: 0.6921 - val_loss: 4.8609 - val_accuracy: 0.6620 - 7s/epoch - 4ms/step
# Epoch 19/50
# 1860/1860 - 6s - loss: 5.1600 - accuracy: 0.6887 - val_loss: 2.6384 - val_accuracy: 0.7205 - 6s/epoch - 3ms/step
# Epoch 20/50
# 1860/1860 - 6s - loss: 4.6589 - accuracy: 0.6903 - val_loss: 9.5460 - val_accuracy: 0.5927 - 6s/epoch - 3ms/step
# Epoch 21/50
# 1860/1860 - 6s - loss: 4.6032 - accuracy: 0.6947 - val_loss: 9.7281 - val_accuracy: 0.6039 - 6s/epoch - 3ms/step
# Epoch 22/50
# 1860/1860 - 6s - loss: 4.7951 - accuracy: 0.6929 - val_loss: 1.2779 - val_accuracy: 0.7748 - 6s/epoch - 3ms/step
# Epoch 23/50
# 1860/1860 - 7s - loss: 4.1722 - accuracy: 0.6967 - val_loss: 9.8961 - val_accuracy: 0.6009 - 7s/epoch - 3ms/step
# Epoch 24/50
# 1860/1860 - 6s - loss: 3.5827 - accuracy: 0.7053 - val_loss: 7.3527 - val_accuracy: 0.6059 - 6s/epoch - 3ms/step
# Epoch 25/50
# 1860/1860 - 6s - loss: 3.9032 - accuracy: 0.6936 - val_loss: 1.1708 - val_accuracy: 0.7836 - 6s/epoch - 3ms/step
# Epoch 26/50
# 1860/1860 - 6s - loss: 3.9683 - accuracy: 0.6941 - val_loss: 1.1173 - val_accuracy: 0.7789 - 6s/epoch - 3ms/step
# Epoch 27/50
# 1860/1860 - 6s - loss: 2.8473 - accuracy: 0.7113 - val_loss: 1.3146 - val_accuracy: 0.7532 - 6s/epoch - 3ms/step
# Epoch 28/50
# 1860/1860 - 7s - loss: 3.2898 - accuracy: 0.6986 - val_loss: 1.0346 - val_accuracy: 0.7827 - 7s/epoch - 4ms/step
# Epoch 29/50
# 1860/1860 - 6s - loss: 3.6372 - accuracy: 0.6912 - val_loss: 1.2050 - val_accuracy: 0.7529 - 6s/epoch - 3ms/step
# Epoch 30/50
# 1860/1860 - 6s - loss: 2.7675 - accuracy: 0.7051 - val_loss: 2.3266 - val_accuracy: 0.6871 - 6s/epoch - 3ms/step
# Epoch 31/50
# 1860/1860 - 6s - loss: 2.4761 - accuracy: 0.7121 - val_loss: 1.6426 - val_accuracy: 0.7149 - 6s/epoch - 3ms/step
# Epoch 32/50
# 1860/1860 - 6s - loss: 2.5628 - accuracy: 0.7038 - val_loss: 0.8426 - val_accuracy: 0.7781 - 6s/epoch - 3ms/step
# Epoch 33/50
# 1860/1860 - 6s - loss: 2.3371 - accuracy: 0.7027 - val_loss: 3.4767 - val_accuracy: 0.6275 - 6s/epoch - 3ms/step
# Epoch 34/50
# 1860/1860 - 6s - loss: 2.1057 - accuracy: 0.7091 - val_loss: 1.8846 - val_accuracy: 0.6977 - 6s/epoch - 3ms/step
# Epoch 35/50
# 1860/1860 - 7s - loss: 1.7991 - accuracy: 0.7100 - val_loss: 1.0652 - val_accuracy: 0.7452 - 7s/epoch - 4ms/step
# Epoch 36/50
# 1860/1860 - 6s - loss: 1.6696 - accuracy: 0.7071 - val_loss: 4.7713 - val_accuracy: 0.5750 - 6s/epoch - 3ms/step
# Epoch 37/50
# 1860/1860 - 6s - loss: 1.2884 - accuracy: 0.7163 - val_loss: 0.5626 - val_accuracy: 0.7790 - 6s/epoch - 3ms/step
# Epoch 38/50
# 1860/1860 - 6s - loss: 1.0043 - accuracy: 0.7158 - val_loss: 0.5318 - val_accuracy: 0.7662 - 6s/epoch - 3ms/step
# Epoch 39/50
# 1860/1860 - 6s - loss: 0.6751 - accuracy: 0.7223 - val_loss: 0.6640 - val_accuracy: 0.6800 - 6s/epoch - 3ms/step
# Epoch 40/50
# 1860/1860 - 6s - loss: 0.5785 - accuracy: 0.7300 - val_loss: 0.6178 - val_accuracy: 0.7143 - 6s/epoch - 3ms/step
# Epoch 41/50
# 1860/1860 - 6s - loss: 0.5528 - accuracy: 0.7355 - val_loss: 0.4607 - val_accuracy: 0.7745 - 6s/epoch - 3ms/step
# Epoch 42/50
# 1860/1860 - 6s - loss: 0.5405 - accuracy: 0.7345 - val_loss: 0.5280 - val_accuracy: 0.7261 - 6s/epoch - 3ms/step
# Epoch 43/50
# 1860/1860 - 6s - loss: 0.5472 - accuracy: 0.7289 - val_loss: 0.4707 - val_accuracy: 0.7821 - 6s/epoch - 3ms/step
# Epoch 44/50
# 1860/1860 - 6s - loss: 0.5300 - accuracy: 0.7398 - val_loss: 0.4698 - val_accuracy: 0.7819 - 6s/epoch - 3ms/step
# Epoch 45/50
# 1860/1860 - 6s - loss: 0.5398 - accuracy: 0.7311 - val_loss: 0.4747 - val_accuracy: 0.7810 - 6s/epoch - 3ms/step
# Epoch 46/50
# 1860/1860 - 6s - loss: 0.5412 - accuracy: 0.7309 - val_loss: 0.6084 - val_accuracy: 0.6833 - 6s/epoch - 3ms/step
# Epoch 47/50
# 1860/1860 - 6s - loss: 0.5377 - accuracy: 0.7332 - val_loss: 0.4965 - val_accuracy: 0.7626 - 6s/epoch - 3ms/step
# Epoch 48/50
# 1860/1860 - 6s - loss: 0.5495 - accuracy: 0.7286 - val_loss: 0.4945 - val_accuracy: 0.7565 - 6s/epoch - 3ms/step
# Epoch 49/50
# 1860/1860 - 6s - loss: 0.5422 - accuracy: 0.7320 - val_loss: 0.5785 - val_accuracy: 0.6931 - 6s/epoch - 3ms/step
# Epoch 50/50
# 1860/1860 - 6s - loss: 0.5393 - accuracy: 0.7331 - val_loss: 0.5032 - val_accuracy: 0.7498 - 6s/epoch - 3ms/step

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper left')
plt.show()
print()
plt.plot(history.history["loss"])
plt.plot(history.history["val_loss"])
plt.title("model loss")
plt.xlabel("epoch")
plt.ylabel("loss")
plt.legend(["train", "val"], loc="upper left")
plt.show()

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                132
#
#  dense_1 (Dense)             (None, 10)                130
#
#  dense_2 (Dense)             (None, 2)                 22
#
# =================================================================
# Total params: 284 (1.11 KB)
# Trainable params: 284 (1.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
