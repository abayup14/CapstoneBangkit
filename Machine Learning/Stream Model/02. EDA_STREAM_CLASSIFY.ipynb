# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('stream_classify_preprocessing.csv')
df.head(20)
# Out:
#     Unnamed: 0  JSKR_LINKAGE_KEY  STREAM_PLACEMENT_DESC  GENDER  INDIGENOUS  \
# 0            0                 1                      1       2           0
# 1            1                 2                      2       2           0
# 2            2                 7                      2       1           0
# 3            3                12                      2       2           0
# 4            4                13                      1       2           0
# 5            5                14                      2       1           0
# 6            6                15                      1       2           0
# 7            7                16                      2       1           0
# 8            8                17                      2       1           1
# 9            9                18                      1       1           0
# 10          10                18                      1       1           0
# 11          11                19                      2       2           0
# 12          12                24                      1       1           1
# 13          13                25                      2       1           0
# 14          14                26                      1       2           0
# 15          15                27                      2       2           0
# 16          16                28                      2       1           0
# 17          17                29                      2       1           0
# 18          18                30                      1       1           0
# 19          19                31                      1       2           0
#
#     HOMELESS  PWD  CALD  REFUGEE  EX_OFFENDER  AGE_GROUP  UE_GROUP  \
# 0          0    0     1        0            0          6         1
# 1          1    0     0        0            0          3         3
# 2          0    1     0        0            0          4         4
# 3          1    1     0        0            0          4         3
# 4          0    0     0        0            0          1         1
# 5          0    1     0        0            0          2         4
# 6          0    0     0        0            0          3         1
# 7          1    1     0        0            0          3         4
# 8          0    1     0        0            1          5         2
# 9          0    1     0        0            0          4         2
# 10         0    1     0        0            0          5         2
# 11         0    1     0        0            0          5         4
# 12         0    0     0        0            1          4         1
# 13         0    1     0        0            1          4         1
# 14         1    1     1        0            1          4         3
# 15         0    1     1        1            0          4         3
# 16         0    0     0        0            0          2         3
# 17         0    1     0        0            1          4         4
# 18         0    0     0        0            0          7         1
# 19         0    0     1        1            0          4         1
#
#     EDUCATION_ADJ
# 0               9
# 1               5
# 2               2
# 3               3
# 4               3
# 5               4
# 6               4
# 7               2
# 8               3
# 9               7
# 10              7
# 11              2
# 12              2
# 13              8
# 14              4
# 15              1
# 16              2
# 17              3
# 18              3
# 19              7

# %%
#EDA
# Check the summary statistics of the dataframe
print(df.describe())
# Out:
#           Unnamed: 0  JSKR_LINKAGE_KEY  STREAM_PLACEMENT_DESC         GENDER  \
# count  485972.000000     485972.000000          485972.000000  485972.000000
# mean   242985.500000     423007.810765               1.251210       1.419627
# std    140288.176847     270699.192245               0.433709       0.493498
# min         0.000000          1.000000               1.000000       1.000000
# 25%    121492.750000     176844.750000               1.000000       1.000000
# 50%    242985.500000     406187.000000               1.000000       1.000000
# 75%    364478.250000     660217.500000               2.000000       2.000000
# max    485971.000000     912603.000000               2.000000       2.000000
#
#           INDIGENOUS       HOMELESS            PWD           CALD  \
# count  485972.000000  485972.000000  485972.000000  485972.000000
# mean        0.137710       0.140889       0.276658       0.172921
# std         0.344595       0.347907       0.447346       0.378180
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       1.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#              REFUGEE    EX_OFFENDER      AGE_GROUP       UE_GROUP  \
# count  485972.000000  485972.000000  485972.000000  485972.000000
# mean        0.061108       0.143027       3.894652       2.229556
# std         0.239529       0.350100       1.869767       1.069735
# min         0.000000       0.000000       1.000000       1.000000
# 25%         0.000000       0.000000       2.000000       1.000000
# 50%         0.000000       0.000000       4.000000       2.000000
# 75%         0.000000       0.000000       5.000000       3.000000
# max         1.000000       1.000000       8.000000       4.000000
#
#        EDUCATION_ADJ
# count  485972.000000
# mean        4.394117
# std         2.023108
# min         1.000000
# 25%         3.000000
# 50%         4.000000
# 75%         6.000000
# max        13.000000

# %% [markdown]
# REGION EDA START

# %%
# Check for missing values
print(df.isnull().sum())
#Result -> tidak ada missing values
# Out:
# Unnamed: 0               0
# JSKR_LINKAGE_KEY         0
# STREAM_PLACEMENT_DESC    0
# GENDER                   0
# INDIGENOUS               0
# HOMELESS                 0
# PWD                      0
# CALD                     0
# REFUGEE                  0
# EX_OFFENDER              0
# AGE_GROUP                0
# UE_GROUP                 0
# EDUCATION_ADJ            0
# dtype: int64

# %%
# Visualize the distribution of each feature
def plot_distribution(column_index=0):
    plt.figure(figsize=(10, 5))
    sns.histplot(data=df, x=df.columns[column_index], kde=True)
    plt.title(f'Distribution of {df.columns[column_index]}')
    plt.show()
    
# plot_distribution(0)
plot_distribution(1)
# plot_distribution(2)
# plot_distribution(3)
# plot_distribution(4)

#ini di uncomment kalau mau ngeplot semua column
# for column in df.columns:
#     plt.figure(figsize=(10, 5))
#     sns.histplot(data=df, x=column, kde=True)
#     plt.title(f'Distribution of {column}')
#     plt.show()

# %%
# Check the correlation between features
plt.figure(figsize=(10, 8))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %% [markdown]
# #REGION EDA END

# %% [markdown]
# #REGION OUTLIER DETECTION START
